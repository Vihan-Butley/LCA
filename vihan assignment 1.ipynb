# %%
#assignment 1

player_list = ["messi","ronaldo" ,"pele" , "maradona"]

print("\nPlayer List:")
print(player_list)

player_tuple = ("messi","ronaldo" , "pele" , "maradona")

print("\nPlayer Tuple:")
print(player_tuple)

#create a dictionary
player_dict = {1:"messi" , 2:"ronaldo" , 3:"pele" , 4:"maradona"}

print("\nPLAYER DICTIONARY")

player_dict[5]="maldini"
print("\nAfter Adding:")
print(player_dict)

player_dict[5]="vihan"
print("\nUpdate:")
print(player_dict)

del player_dict[4]
print(player_dict)
# Out:
# Player List:
# ['messi', 'ronaldo', 'pele', 'maradona']
#
# Player Tuple:
# ('messi', 'ronaldo', 'pele', 'maradona')
#
# PLAYER DICTIONARY
#
# After Adding:
# {1: 'messi', 2: 'ronaldo', 3: 'pele', 4: 'maradona', 5: 'maldini'}
#
# Update:
# {1: 'messi', 2: 'ronaldo', 3: 'pele', 4: 'maradona', 5: 'vihan'}
# {1: 'messi', 2: 'ronaldo', 3: 'pele', 5: 'vihan'}
